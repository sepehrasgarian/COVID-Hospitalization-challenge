# %% [markdown]
# # COVID-19 Hospitalization Challenge
#
# Check the README.md file for challange details.

# %%
import pandas as pd
import numpy as np
from matplotlib.dates import DateFormatter
import json
import matplotlib.pyplot as plt
import os, sys
import seaborn as sns
import random
from datetime import datetime, date
from scipy import stats


plt.style.use('seaborn') # ggplot
pd.options.display.precision = 2
pd.options.display.max_rows = 100
pd.options.display.max_columns = None ### watch out

# %%
# %pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /opt/conda/envs/nlp/lib/python3.8/site-packages (3.0.10)
# Requirement already satisfied: et-xmlfile in /opt/conda/envs/nlp/lib/python3.8/site-packages (from openpyxl) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Load data and merge files

# %%
filenames = [
    '../data/original_data/Canada_Hosp1_COVID_InpatientData.xlsx',
    '../data/original_data/Canada_Hosp2_COVID_InpatientData.xlsx'
]

# %%
df_list = []

for file in filenames:
    tmp1 = pd.read_excel(file, sheet_name=0)
    tmp2 = pd.read_excel(file, sheet_name=2)
    df1 = tmp1.merge(tmp2.drop(columns=['id']), left_on='id', right_on='parent_id', how='inner')
    df_list.append(df1)

df = pd.concat(df_list)

print(df.shape)
display(df.head(3))
# Out:
# (707, 65)
#    id reason_for_admission  age     sex ethnicity ethnicity_other  height  \
# 0   1        Fever [R50.9]   74    Male      "[]"             NaN     NaN
# 1   2    Pneumonia [J18.9]   61  Female      "[]"             NaN   154.9
# 2   3    Pneumonia [J18.9]   58  Female      "[]"             NaN     NaN
#
#    weight                                comorbidities  \
# 0     NaN  "[\"Hypertension\",\"Diabetes\",\"Other\"]"
# 1    73.6               "[\"Hypertension\",\"Other\"]"
# 2     NaN                         "[\"Hypertension\"]"
#
#                                  comorbidities_other received_covid_vaccine  \
# 0  GERD (gastroesophageal reflux disease), Dement...                    NaN
# 1  Closed fracture of fifth metatarsal bone, Dive...                    NaN
# 2                                                NaN                    NaN
#
#   covid_vaccine                                        medications  \
# 0           NaN  "[{\"medications\":\"TYLENOL EXTRA STRENGTH\",...
# 1           NaN  "[{\"medications\":\"CANDESARTAN\",\"dosage\":...
# 2           NaN  "[{\"medications\":\"\",\"dosage\":\"\",\"freq...
#
#   smoking_history  year_they_quit previous_er_visit_within_14_days  \
# 0             NaN             NaN                               No
# 1             NaN             NaN                               No
# 2             NaN             NaN                               No
#
#   admission_disposition  systolic_blood_pressure  diastolic_blood_pressure  \
# 0                  WARD                     99.0                      62.0
# 1                  WARD                    122.0                      77.0
# 2                  WARD                    109.0                      72.0
#
#    heart_rate  respiratory_rate  oxygen_saturation  temperature  motor  \
# 0        85.0              20.0               93.0         37.5    6.0
# 1        93.0              36.0               88.0         38.0    6.0
# 2        73.0              24.0               91.0         38.3    6.0
#
#    verbal  eye intubated   wbc   rbc  hemoglobin  hematocrit   mcv   mch  \
# 0     4.0  4.0        No  11.0  5.63       132.0        0.41  72.1  23.4
# 1     5.0  4.0        No   5.0  4.49       121.0        0.35  78.6  26.9
# 2     5.0  3.0        No   6.2  4.31       119.0        0.36  84.0  27.6
#
#     mchc   rdw  platelet_count aptt_aptr    pt   alt   ast  serum_creatinine  \
# 0  325.0  18.5           128.0        44  14.1  53.0  49.0             165.0
# 1  343.0  14.2           236.0        28  12.9  68.0  68.0              49.0
# 2  329.0  12.5           249.0       NaN   NaN  52.0  76.0              71.0
#
#    sodium  potassium  total_serum_bilirubin  lactate  pao2  pao2_fio2  ph  \
# 0   135.0        3.9                   10.0      2.3   NaN        NaN NaN
# 1   137.0        3.8                   12.0      1.5   NaN        NaN NaN
# 2   135.0        3.7                    7.0      1.0   NaN        NaN NaN
#
#    high_senstivity_cardiac_troponin  esr  inr  ferritin d_dimer    crp  \
# 0                               NaN  NaN  1.1       NaN     NaN  223.0
# 1                               NaN  NaN  1.0       NaN    2354   95.6
# 2                               NaN  NaN  NaN       NaN     NaN    NaN
#
#    hs_crp  parent_id did_the_patient_expire_in_hospital  \
# 0     NaN          1                                Yes
# 1     NaN          2                                 No
# 2     NaN          3                                 No
#
#               reason_for_death  days_in_hospital_prior_to_expiration  \
# 0  Hospital acquired Pneumonia                                  20.0
# 1                          NaN                                   NaN
# 2                          NaN                                   NaN
#
#    hospital_length_of_stay  icu_length_of_stay  \
# 0                       21                 NaN
# 1                        5                 NaN
# 2                        7                 NaN
#
#    days_in_hospital_prior_to_icu_admission  time_on_mechanical_ventilation  \
# 0                                      NaN                             NaN
# 1                                      NaN                             NaN
# 2                                      NaN                             NaN
#
#    days_in_hospital_prior_to_mechanical_ventilation  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
#
#    days_to_first_covid19_test_negative
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN

# %% [markdown]
# ## Clean up and simplify the features

# %%
df = df.rename(columns={'did_the_patient_expire_in_hospital': 'did_the_patient_die_in_hospital',
                       'days_in_hospital_prior_to_expiration': 'days_in_hospital_prior_to_death'})
df['smoking_history'].replace('Smoker:.+', value='Smoker', regex=True, inplace=True)

def to_list(value):
    """Formated as nested json"""
    return json.loads(json.loads(value))


df['comorbidities'] = df['comorbidities'].apply(to_list)
print(df.shape)
df.head()
# Out:
# (707, 65)
#    id                        reason_for_admission  age     sex ethnicity  \
# 0   1                               Fever [R50.9]   74    Male      "[]"
# 1   2                           Pneumonia [J18.9]   61  Female      "[]"
# 2   3                           Pneumonia [J18.9]   58  Female      "[]"
# 3   4  Suspected COVID-19 virus infection [U07.2]   94    Male      "[]"
# 4   5  Febrile respiratory illness [J98.9, R50.9]   91    Male      "[]"
#
#   ethnicity_other  height  weight  \
# 0             NaN     NaN     NaN
# 1             NaN   154.9    73.6
# 2             NaN     NaN     NaN
# 3             NaN   182.8    66.2
# 4             NaN     NaN     NaN
#
#                                        comorbidities  \
# 0                    [Hypertension, Diabetes, Other]
# 1                              [Hypertension, Other]
# 2                                     [Hypertension]
# 3                              [Hypertension, Other]
# 4  [Chronic cardiac disease (not hypertension), H...
#
#                                  comorbidities_other received_covid_vaccine  \
# 0  GERD (gastroesophageal reflux disease), Dement...                    NaN
# 1  Closed fracture of fifth metatarsal bone, Dive...                    NaN
# 2                                                NaN                    NaN
# 3  Parkinson's Disease, Back pain, Benign Prostat...                    NaN
# 4  TAVI, Atrial fibrillation, Gastric Reflux, Pac...                    NaN
#
#   covid_vaccine                                        medications  \
# 0           NaN  "[{\"medications\":\"TYLENOL EXTRA STRENGTH\",...
# 1           NaN  "[{\"medications\":\"CANDESARTAN\",\"dosage\":...
# 2           NaN  "[{\"medications\":\"\",\"dosage\":\"\",\"freq...
# 3           NaN  "[{\"medications\":\"ACETYLSALICYLIC ACID  TAB...
# 4           NaN  "[{\"medications\":\"TRAZODONE\",\"dosage\":\"...
#
#   smoking_history  year_they_quit previous_er_visit_within_14_days  \
# 0             NaN             NaN                               No
# 1             NaN             NaN                               No
# 2             NaN             NaN                               No
# 3             NaN             NaN                               No
# 4       Ex-smoker             NaN                               No
#
#   admission_disposition  systolic_blood_pressure  diastolic_blood_pressure  \
# 0                  WARD                     99.0                      62.0
# 1                  WARD                    122.0                      77.0
# 2                  WARD                    109.0                      72.0
# 3                  WARD                    165.0                      71.0
# 4                  WARD                    131.0                      76.0
#
#    heart_rate  respiratory_rate  oxygen_saturation  temperature  motor  \
# 0        85.0              20.0               93.0         37.5    6.0
# 1        93.0              36.0               88.0         38.0    6.0
# 2        73.0              24.0               91.0         38.3    6.0
# 3        92.0              16.0               96.0         37.5    6.0
# 4        60.0              18.0               95.0         38.2    6.0
#
#    verbal  eye intubated   wbc   rbc  hemoglobin  hematocrit    mcv   mch  \
# 0     4.0  4.0        No  11.0  5.63       132.0        0.41   72.1  23.4
# 1     5.0  4.0        No   5.0  4.49       121.0        0.35   78.6  26.9
# 2     5.0  3.0        No   6.2  4.31       119.0        0.36   84.0  27.6
# 3     5.0  4.0        No   5.2  4.18       137.0        0.43  102.4  32.8
# 4     5.0  4.0        No   4.4  4.65       127.0        0.41   88.4  27.3
#
#     mchc   rdw  platelet_count aptt_aptr    pt   alt   ast  serum_creatinine  \
# 0  325.0  18.5           128.0        44  14.1  53.0  49.0             165.0
# 1  343.0  14.2           236.0        28  12.9  68.0  68.0              49.0
# 2  329.0  12.5           249.0       NaN   NaN  52.0  76.0              71.0
# 3  320.0  17.2            98.0       NaN   NaN   6.0  24.0             146.0
# 4  309.0  17.6            74.0       NaN   NaN  17.0  26.0             109.0
#
#    sodium  potassium  total_serum_bilirubin  lactate  pao2  pao2_fio2  ph  \
# 0   135.0        3.9                   10.0      2.3   NaN        NaN NaN
# 1   137.0        3.8                   12.0      1.5   NaN        NaN NaN
# 2   135.0        3.7                    7.0      1.0   NaN        NaN NaN
# 3   135.0        2.8                   10.0      4.5   NaN        NaN NaN
# 4   142.0        3.8                   19.0      3.2   NaN        NaN NaN
#
#    high_senstivity_cardiac_troponin  esr  inr  ferritin d_dimer    crp  \
# 0                               NaN  NaN  1.1       NaN     NaN  223.0
# 1                               NaN  NaN  1.0       NaN    2354   95.6
# 2                               NaN  NaN  NaN       NaN     NaN    NaN
# 3                               NaN  NaN  NaN       NaN     NaN    NaN
# 4                               NaN  NaN  NaN       NaN     NaN    NaN
#
#    hs_crp  parent_id did_the_patient_die_in_hospital  \
# 0     NaN          1                             Yes
# 1     NaN          2                              No
# 2     NaN          3                              No
# 3     NaN          4                             Yes
# 4     NaN          5                             Yes
#
#               reason_for_death  days_in_hospital_prior_to_death  \
# 0  Hospital acquired Pneumonia                             20.0
# 1                          NaN                              NaN
# 2                          NaN                              NaN
# 3           COVID-19 Pneumonia                              9.0
# 4              COVID-Pneumonia                              9.0
#
#    hospital_length_of_stay  icu_length_of_stay  \
# 0                       21                 NaN
# 1                        5                 NaN
# 2                        7                 NaN
# 3                        9                 NaN
# 4                        9                 NaN
#
#    days_in_hospital_prior_to_icu_admission  time_on_mechanical_ventilation  \
# 0                                      NaN                             NaN
# 1                                      NaN                             NaN
# 2                                      NaN                             NaN
# 3                                      NaN                             NaN
# 4                                      NaN                             NaN
#
#    days_in_hospital_prior_to_mechanical_ventilation  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#    days_to_first_covid19_test_negative
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN

# %%
# To drop
# too much null values, harder to impute
always_null = ['high_senstivity_cardiac_troponin', 'hs_crp', 'received_covid_vaccine', 'covid_vaccine', 'ethnicity', 
            'ethnicity_other', 'esr', 'ferritin', 'pao2', 'pao2_fio2', 'ph']
ids = ['parent_id', 'id', 'days_in_hospital_prior_to_death']
# reduce complexity, those columns needs time to process correctly
exclude = ['medications', 'comorbidities_other', 'year_they_quit', 'reason_for_admission', 
           'days_to_first_covid19_test_negative', 'reason_for_death']


# will drop for the sake of time, but possible to impute
high_null = ['crp', 'd_dimer', 'inr', 'aptt_aptr']

# will keep those, need to be handled
empty_is_zero = ['reason_for_death', 'days_in_hospital_prior_to_death',  #?
                 'icu_length_of_stay', 'time_on_mechanical_ventilation']
empty_is_infinity = ['days_to_first_covid19_test_negative'] #?


df = df.drop(columns=always_null+ids+high_null+exclude)

# missing values in response, drop them
print('Missing values in response: ', df['did_the_patient_die_in_hospital'].isna().sum())
df = df.dropna(subset='did_the_patient_die_in_hospital')


print(df.shape)
df.head()
# Out:
# Missing values in response:  6
# (701, 41)
#    age     sex  height  weight  \
# 0   74    Male     NaN     NaN
# 1   61  Female   154.9    73.6
# 2   58  Female     NaN     NaN
# 3   94    Male   182.8    66.2
# 4   91    Male     NaN     NaN
#
#                                        comorbidities smoking_history  \
# 0                    [Hypertension, Diabetes, Other]             NaN
# 1                              [Hypertension, Other]             NaN
# 2                                     [Hypertension]             NaN
# 3                              [Hypertension, Other]             NaN
# 4  [Chronic cardiac disease (not hypertension), H...       Ex-smoker
#
#   previous_er_visit_within_14_days admission_disposition  \
# 0                               No                  WARD
# 1                               No                  WARD
# 2                               No                  WARD
# 3                               No                  WARD
# 4                               No                  WARD
#
#    systolic_blood_pressure  diastolic_blood_pressure  heart_rate  \
# 0                     99.0                      62.0        85.0
# 1                    122.0                      77.0        93.0
# 2                    109.0                      72.0        73.0
# 3                    165.0                      71.0        92.0
# 4                    131.0                      76.0        60.0
#
#    respiratory_rate  oxygen_saturation  temperature  motor  verbal  eye  \
# 0              20.0               93.0         37.5    6.0     4.0  4.0
# 1              36.0               88.0         38.0    6.0     5.0  4.0
# 2              24.0               91.0         38.3    6.0     5.0  3.0
# 3              16.0               96.0         37.5    6.0     5.0  4.0
# 4              18.0               95.0         38.2    6.0     5.0  4.0
#
#   intubated   wbc   rbc  hemoglobin  hematocrit    mcv   mch   mchc   rdw  \
# 0        No  11.0  5.63       132.0        0.41   72.1  23.4  325.0  18.5
# 1        No   5.0  4.49       121.0        0.35   78.6  26.9  343.0  14.2
# 2        No   6.2  4.31       119.0        0.36   84.0  27.6  329.0  12.5
# 3        No   5.2  4.18       137.0        0.43  102.4  32.8  320.0  17.2
# 4        No   4.4  4.65       127.0        0.41   88.4  27.3  309.0  17.6
#
#    platelet_count    pt   alt   ast  serum_creatinine  sodium  potassium  \
# 0           128.0  14.1  53.0  49.0             165.0   135.0        3.9
# 1           236.0  12.9  68.0  68.0              49.0   137.0        3.8
# 2           249.0   NaN  52.0  76.0              71.0   135.0        3.7
# 3            98.0   NaN   6.0  24.0             146.0   135.0        2.8
# 4            74.0   NaN  17.0  26.0             109.0   142.0        3.8
#
#    total_serum_bilirubin  lactate did_the_patient_die_in_hospital  \
# 0                   10.0      2.3                             Yes
# 1                   12.0      1.5                              No
# 2                    7.0      1.0                              No
# 3                   10.0      4.5                             Yes
# 4                   19.0      3.2                             Yes
#
#    hospital_length_of_stay  icu_length_of_stay  \
# 0                       21                 NaN
# 1                        5                 NaN
# 2                        7                 NaN
# 3                        9                 NaN
# 4                        9                 NaN
#
#    days_in_hospital_prior_to_icu_admission  time_on_mechanical_ventilation  \
# 0                                      NaN                             NaN
# 1                                      NaN                             NaN
# 2                                      NaN                             NaN
# 3                                      NaN                             NaN
# 4                                      NaN                             NaN
#
#    days_in_hospital_prior_to_mechanical_ventilation
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN

# %%
df.to_csv('../data/challenge_data/covid_hospitalization_dataset.csv', index=False)
